# %% [markdown]
# # Raster Datasets

# %%
import ouroboros as ob

# %%
gdb = "USGS_PP406.gdb"
ob.list_rasters(gdb)
# Out:
# ['USGS_PP406']

# %%
ob.raster_to_tif("USGS_PP406.gdb", "USGS_PP406")

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("USGS_PP406.tif")
plt.imshow(img, cmap=None)
