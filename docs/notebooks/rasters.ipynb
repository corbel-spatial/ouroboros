# %% [markdown]
# # Raster Datasets

# %%
import ouroboros as ob

# %%
gdb = "USGS_PP406.gdb"
ob.list_rasters(gdb)
# Out:
# ['USGS_PP406']

# %%
ob.raster_to_tif("USGS_PP406.gdb", "USGS_PP406")
# Out:
# Opened: USGS_PP406.gdb\USGS_PP406
#
# Saved: USGS_PP406.tif

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread("USGS_PP406.tif")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img, cmap=None)
